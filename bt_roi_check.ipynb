# %%
import os
import cv2

def detect_roi(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Perform thresholding to segment regions of interest
    _, thresholded = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # If any contours are found, the image contains regions of interest
    if len(contours) > 0:
        return True
    else:
        return False

# Path to the directory containing images
directory = "BT_V1/Training/meningioma"

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        image_path = os.path.join(directory, filename)
        image = cv2.imread(image_path)

        # Check if the image contains regions of interest
        if detect_roi(image):
            print(f"{filename}: The image contains regions of interest (ROIs).")
        else:
            print(f"{filename}: No regions of interest (ROIs) found in the image.")
# Out:
# Tr-meTr_0000.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0001.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0002.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0003.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0004.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0005.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0006.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0007.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0008.jpg: The image contains regions of interest (ROIs).
# Tr-meTr_0009.jpg: The image contains regions of interest (ROIs).
# Tr-me_0010.jpg: The image contains regions of interest (ROIs).
# Tr-me_0011.jpg: The image contains regions of interest (ROIs).
# Tr-me_0012.jpg: The image contains regions of interest (ROIs).
# Tr-me_0013.jpg: The image contains regions of interest (ROIs).
# Tr-me_0014.jpg: The image contains regions of interest (ROIs).
# Tr-me_0015.jpg: The image contains regions of interest (ROIs).
# Tr-me_0016.jpg: The image contains regions of interest (ROIs).
# Tr-me_0017.jpg: The image contains regions of interest (ROIs).
# Tr-me_0018.jpg: The image contains regions of interest (ROIs).
# Tr-me_0019.jpg: The image contains regions of interest (ROIs).
# Tr-me_0020.jpg: The image contains regions of interest (ROIs).
# Tr-me_0021.jpg: The image contains regions of interest (ROIs).
# Tr-me_0022.jpg: The image contains regions of interest (ROIs).
# Tr-me_0023.jpg: The image contains regions of interest (ROIs).
# Tr-me_0024.jpg: The image contains regions of interest (ROIs).
# Tr-me_0025.jpg: The image contains regions of interest (ROIs).
# Tr-me_0026.jpg: The image contains regions of interest (ROIs).
# Tr-me_0027.jpg: The image contains regions of interest (ROIs).
# Tr-me_0028.jpg: The image contains regions of interest (ROIs).
# Tr-me_0029.jpg: The image contains regions of interest (ROIs).
# Tr-me_0030.jpg: The image contains regions of interest (ROIs).
# Tr-me_0031.jpg: The image contains regions of interest (ROIs).
# Tr-me_0032.jpg: The image contains regions of interest (ROIs).
# Tr-me_0033.jpg: The image contains regions of interest (ROIs).
# Tr-me_0034.jpg: The image contains regions of interest (ROIs).
# Tr-me_0035.jpg: The image contains regions of interest (ROIs).
# Tr-me_0036.jpg: The image contains regions of interest (ROIs).
# Tr-me_0037.jpg: The image contains regions of interest (ROIs).
# Tr-me_0038.jpg: The image contains regions of interest (ROIs).
# Tr-me_0039.jpg: The image contains regions of interest (ROIs).
# Tr-me_0040.jpg: The image contains regions of interest (ROIs).
# Tr-me_0041.jpg: The image contains regions of interest (ROIs).
# Tr-me_0042.jpg: The image contains regions of interest (ROIs).
# Tr-me_0043.jpg: The image contains regions of interest (ROIs).
# Tr-me_0044.jpg: The image contains regions of interest (ROIs).
# Tr-me_0045.jpg: The image contains regions of interest (ROIs).
# Tr-me_0046.jpg: The image contains regions of interest (ROIs).
# Tr-me_0047.jpg: The image contains regions of interest (ROIs).
# Tr-me_0048.jpg: The image contains regions of interest (ROIs).
# Tr-me_0049.jpg: The image contains regions of interest (ROIs).
# Tr-me_0050.jpg: The image contains regions of interest (ROIs).
# Tr-me_0051.jpg: The image contains regions of interest (ROIs).
# Tr-me_0052.jpg: The image contains regions of interest (ROIs).
# Tr-me_0053.jpg: The image contains regions of interest (ROIs).
# Tr-me_0054.jpg: The image contains regions of interest (ROIs).
# Tr-me_0055.jpg: The image contains regions of interest (ROIs).
# Tr-me_0056.jpg: The image contains regions of interest (ROIs).
# Tr-me_0057.jpg: The image contains regions of interest (ROIs).
# Tr-me_0058.jpg: The image contains regions of interest (ROIs).
# Tr-me_0059.jpg: The image contains regions of interest (ROIs).
# Tr-me_0060.jpg: The image contains regions of interest (ROIs).
# Tr-me_0061.jpg: The image contains regions of interest (ROIs).
# Tr-me_0062.jpg: The image contains regions of interest (ROIs).
# Tr-me_0063.jpg: The image contains regions of interest (ROIs).
# Tr-me_0064.jpg: The image contains regions of interest (ROIs).
# Tr-me_0065.jpg: The image contains regions of interest (ROIs).
# Tr-me_0066.jpg: The image contains regions of interest (ROIs).
# Tr-me_0067.jpg: The image contains regions of interest (ROIs).
# Tr-me_0068.jpg: The image contains regions of interest (ROIs).
# Tr-me_0069.jpg: The image contains regions of interest (ROIs).
# Tr-me_0070.jpg: The image contains regions of interest (ROIs).
# Tr-me_0071.jpg: The image contains regions of interest (ROIs).
# Tr-me_0072.jpg: The image contains regions of interest (ROIs).
# Tr-me_0073.jpg: The image contains regions of interest (ROIs).
# Tr-me_0074.jpg: The image contains regions of interest (ROIs).
# Tr-me_0075.jpg: The image contains regions of interest (ROIs).
# Tr-me_0076.jpg: The image contains regions of interest (ROIs).
# Tr-me_0077.jpg: The image contains regions of interest (ROIs).
# Tr-me_0078.jpg: The image contains regions of interest (ROIs).
# Tr-me_0079.jpg: The image contains regions of interest (ROIs).
# Tr-me_0080.jpg: The image contains regions of interest (ROIs).
# Tr-me_0081.jpg: The image contains regions of interest (ROIs).
# Tr-me_0082.jpg: The image contains regions of interest (ROIs).
# Tr-me_0083.jpg: The image contains regions of interest (ROIs).
# Tr-me_0084.jpg: The image contains regions of interest (ROIs).
# Tr-me_0085.jpg: The image contains regions of interest (ROIs).
# Tr-me_0086.jpg: The image contains regions of interest (ROIs).
# Tr-me_0087.jpg: The image contains regions of interest (ROIs).
# Tr-me_0088.jpg: The image contains regions of interest (ROIs).
# Tr-me_0089.jpg: The image contains regions of interest (ROIs).
# Tr-me_0090.jpg: The image contains regions of interest (ROIs).
# Tr-me_0091.jpg: The image contains regions of interest (ROIs).
# Tr-me_0092.jpg: The image contains regions of interest (ROIs).
# Tr-me_0093.jpg: The image contains regions of interest (ROIs).
# Tr-me_0094.jpg: The image contains regions of interest (ROIs).
# Tr-me_0095.jpg: The image contains regions of interest (ROIs).
# Tr-me_0096.jpg: The image contains regions of interest (ROIs).
# Tr-me_0097.jpg: The image contains regions of interest (ROIs).
# Tr-me_0098.jpg: The image contains regions of interest (ROIs).
# Tr-me_0099.jpg: The image contains regions of interest (ROIs).
# Tr-me_0100.jpg: The image contains regions of interest (ROIs).
# Tr-me_0101.jpg: The image contains regions of interest (ROIs).
# Tr-me_0102.jpg: The image contains regions of interest (ROIs).
# Tr-me_0103.jpg: The image contains regions of interest (ROIs).
# Tr-me_0104.jpg: The image contains regions of interest (ROIs).
# Tr-me_0105.jpg: The image contains regions of interest (ROIs).
# Tr-me_0106.jpg: The image contains regions of interest (ROIs).
# Tr-me_0107.jpg: The image contains regions of interest (ROIs).
# Tr-me_0108.jpg: The image contains regions of interest (ROIs).
# Tr-me_0109.jpg: The image contains regions of interest (ROIs).
# Tr-me_0110.jpg: The image contains regions of interest (ROIs).
# Tr-me_0111.jpg: The image contains regions of interest (ROIs).
# Tr-me_0112.jpg: The image contains regions of interest (ROIs).
# Tr-me_0113.jpg: The image contains regions of interest (ROIs).
# Tr-me_0114.jpg: The image contains regions of interest (ROIs).
# Tr-me_0115.jpg: The image contains regions of interest (ROIs).
# Tr-me_0116.jpg: The image contains regions of interest (ROIs).
# Tr-me_0117.jpg: The image contains regions of interest (ROIs).
# Tr-me_0118.jpg: The image contains regions of interest (ROIs).
# Tr-me_0119.jpg: The image contains regions of interest (ROIs).
# Tr-me_0120.jpg: The image contains regions of interest (ROIs).
# Tr-me_0121.jpg: The image contains regions of interest (ROIs).
# Tr-me_0122.jpg: The image contains regions of interest (ROIs).
# Tr-me_0123.jpg: The image contains regions of interest (ROIs).
# Tr-me_0124.jpg: The image contains regions of interest (ROIs).
# Tr-me_0125.jpg: The image contains regions of interest (ROIs).
# Tr-me_0126.jpg: The image contains regions of interest (ROIs).
# Tr-me_0127.jpg: The image contains regions of interest (ROIs).
# Tr-me_0128.jpg: The image contains regions of interest (ROIs).
# Tr-me_0129.jpg: The image contains regions of interest (ROIs).
# Tr-me_0130.jpg: The image contains regions of interest (ROIs).
# Tr-me_0131.jpg: The image contains regions of interest (ROIs).
# Tr-me_0132.jpg: The image contains regions of interest (ROIs).
# Tr-me_0133.jpg: The image contains regions of interest (ROIs).
# Tr-me_0134.jpg: The image contains regions of interest (ROIs).
# Tr-me_0135.jpg: The image contains regions of interest (ROIs).
# Tr-me_0136.jpg: The image contains regions of interest (ROIs).
# Tr-me_0137.jpg: The image contains regions of interest (ROIs).
# Tr-me_0138.jpg: The image contains regions of interest (ROIs).
# Tr-me_0139.jpg: The image contains regions of interest (ROIs).
# Tr-me_0140.jpg: The image contains regions of interest (ROIs).
# Tr-me_0141.jpg: The image contains regions of interest (ROIs).
# Tr-me_0142.jpg: The image contains regions of interest (ROIs).
# Tr-me_0143.jpg: The image contains regions of interest (ROIs).
# Tr-me_0144.jpg: The image contains regions of interest (ROIs).
# Tr-me_0145.jpg: The image contains regions of interest (ROIs).
# Tr-me_0146.jpg: The image contains regions of interest (ROIs).
# Tr-me_0147.jpg: The image contains regions of interest (ROIs).
# Tr-me_0148.jpg: The image contains regions of interest (ROIs).
# Tr-me_0149.jpg: The image contains regions of interest (ROIs).
# Tr-me_0150.jpg: The image contains regions of interest (ROIs).
# Tr-me_0151.jpg: The image contains regions of interest (ROIs).
# Tr-me_0152.jpg: The image contains regions of interest (ROIs).
# Tr-me_0153.jpg: The image contains regions of interest (ROIs).
# Tr-me_0154.jpg: The image contains regions of interest (ROIs).
# Tr-me_0155.jpg: The image contains regions of interest (ROIs).
# Tr-me_0156.jpg: The image contains regions of interest (ROIs).
# Tr-me_0157.jpg: The image contains regions of interest (ROIs).
# Tr-me_0158.jpg: The image contains regions of interest (ROIs).
# Tr-me_0159.jpg: The image contains regions of interest (ROIs).
# Tr-me_0160.jpg: The image contains regions of interest (ROIs).
# Tr-me_0161.jpg: The image contains regions of interest (ROIs).
# Tr-me_0162.jpg: The image contains regions of interest (ROIs).
# Tr-me_0163.jpg: The image contains regions of interest (ROIs).
# Tr-me_0164.jpg: The image contains regions of interest (ROIs).
# Tr-me_0165.jpg: The image contains regions of interest (ROIs).
# Tr-me_0166.jpg: The image contains regions of interest (ROIs).
# Tr-me_0167.jpg: The image contains regions of interest (ROIs).
# Tr-me_0168.jpg: The image contains regions of interest (ROIs).
# Tr-me_0169.jpg: The image contains regions of interest (ROIs).
# Tr-me_0170.jpg: The image contains regions of interest (ROIs).
# Tr-me_0171.jpg: The image contains regions of interest (ROIs).
# Tr-me_0172.jpg: The image contains regions of interest (ROIs).
# Tr-me_0173.jpg: The image contains regions of interest (ROIs).
# Tr-me_0174.jpg: The image contains regions of interest (ROIs).
# Tr-me_0175.jpg: The image contains regions of interest (ROIs).
# Tr-me_0176.jpg: The image contains regions of interest (ROIs).
# Tr-me_0177.jpg: The image contains regions of interest (ROIs).
# Tr-me_0178.jpg: The image contains regions of interest (ROIs).
# Tr-me_0179.jpg: The image contains regions of interest (ROIs).
# Tr-me_0180.jpg: The image contains regions of interest (ROIs).
# Tr-me_0181.jpg: The image contains regions of interest (ROIs).
# Tr-me_0182.jpg: The image contains regions of interest (ROIs).
# Tr-me_0183.jpg: The image contains regions of interest (ROIs).
# Tr-me_0184.jpg: The image contains regions of interest (ROIs).
# Tr-me_0185.jpg: The image contains regions of interest (ROIs).
# Tr-me_0186.jpg: The image contains regions of interest (ROIs).
# Tr-me_0187.jpg: The image contains regions of interest (ROIs).
# Tr-me_0188.jpg: The image contains regions of interest (ROIs).
# Tr-me_0189.jpg: The image contains regions of interest (ROIs).
# Tr-me_0190.jpg: The image contains regions of interest (ROIs).
# Tr-me_0191.jpg: The image contains regions of interest (ROIs).
# Tr-me_0192.jpg: The image contains regions of interest (ROIs).
# Tr-me_0193.jpg: The image contains regions of interest (ROIs).
# Tr-me_0194.jpg: The image contains regions of interest (ROIs).
# Tr-me_0195.jpg: The image contains regions of interest (ROIs).
# Tr-me_0196.jpg: The image contains regions of interest (ROIs).
# Tr-me_0197.jpg: The image contains regions of interest (ROIs).
# Tr-me_0198.jpg: The image contains regions of interest (ROIs).
# Tr-me_0199.jpg: The image contains regions of interest (ROIs).
# Tr-me_0200.jpg: The image contains regions of interest (ROIs).
# Tr-me_0201.jpg: The image contains regions of interest (ROIs).
# Tr-me_0202.jpg: The image contains regions of interest (ROIs).
# Tr-me_0203.jpg: The image contains regions of interest (ROIs).
# Tr-me_0204.jpg: The image contains regions of interest (ROIs).
# Tr-me_0205.jpg: The image contains regions of interest (ROIs).
# Tr-me_0206.jpg: The image contains regions of interest (ROIs).
# Tr-me_0207.jpg: The image contains regions of interest (ROIs).
# Tr-me_0208.jpg: The image contains regions of interest (ROIs).
# Tr-me_0209.jpg: The image contains regions of interest (ROIs).
# Tr-me_0210.jpg: The image contains regions of interest (ROIs).
# Tr-me_0211.jpg: The image contains regions of interest (ROIs).
# Tr-me_0212.jpg: The image contains regions of interest (ROIs).
# Tr-me_0213.jpg: The image contains regions of interest (ROIs).
# Tr-me_0214.jpg: The image contains regions of interest (ROIs).
# Tr-me_0215.jpg: The image contains regions of interest (ROIs).
# Tr-me_0216.jpg: The image contains regions of interest (ROIs).
# Tr-me_0217.jpg: The image contains regions of interest (ROIs).
# Tr-me_0218.jpg: The image contains regions of interest (ROIs).
# Tr-me_0219.jpg: The image contains regions of interest (ROIs).
# Tr-me_0220.jpg: The image contains regions of interest (ROIs).
# Tr-me_0221.jpg: The image contains regions of interest (ROIs).
# Tr-me_0222.jpg: The image contains regions of interest (ROIs).
# Tr-me_0223.jpg: The image contains regions of interest (ROIs).
# Tr-me_0224.jpg: The image contains regions of interest (ROIs).
# Tr-me_0225.jpg: The image contains regions of interest (ROIs).
# Tr-me_0226.jpg: The image contains regions of interest (ROIs).
# Tr-me_0227.jpg: The image contains regions of interest (ROIs).
# Tr-me_0228.jpg: The image contains regions of interest (ROIs).
# Tr-me_0229.jpg: The image contains regions of interest (ROIs).
# Tr-me_0230.jpg: The image contains regions of interest (ROIs).
# Tr-me_0231.jpg: The image contains regions of interest (ROIs).
# Tr-me_0232.jpg: The image contains regions of interest (ROIs).
# Tr-me_0233.jpg: The image contains regions of interest (ROIs).
# Tr-me_0234.jpg: The image contains regions of interest (ROIs).
# Tr-me_0235.jpg: The image contains regions of interest (ROIs).
# Tr-me_0236.jpg: The image contains regions of interest (ROIs).
# Tr-me_0237.jpg: The image contains regions of interest (ROIs).
# Tr-me_0238.jpg: The image contains regions of interest (ROIs).
# Tr-me_0239.jpg: The image contains regions of interest (ROIs).
# Tr-me_0240.jpg: The image contains regions of interest (ROIs).
# Tr-me_0241.jpg: The image contains regions of interest (ROIs).
# Tr-me_0242.jpg: The image contains regions of interest (ROIs).
# Tr-me_0243.jpg: The image contains regions of interest (ROIs).
# Tr-me_0244.jpg: The image contains regions of interest (ROIs).
# Tr-me_0245.jpg: The image contains regions of interest (ROIs).
# Tr-me_0246.jpg: The image contains regions of interest (ROIs).
# Tr-me_0247.jpg: The image contains regions of interest (ROIs).
# Tr-me_0248.jpg: The image contains regions of interest (ROIs).
# Tr-me_0249.jpg: The image contains regions of interest (ROIs).
# Tr-me_0250.jpg: The image contains regions of interest (ROIs).
# Tr-me_0251.jpg: The image contains regions of interest (ROIs).
# Tr-me_0252.jpg: The image contains regions of interest (ROIs).
# Tr-me_0253.jpg: The image contains regions of interest (ROIs).
# Tr-me_0254.jpg: The image contains regions of interest (ROIs).
# Tr-me_0255.jpg: The image contains regions of interest (ROIs).
# Tr-me_0256.jpg: The image contains regions of interest (ROIs).
# Tr-me_0257.jpg: The image contains regions of interest (ROIs).
# Tr-me_0258.jpg: The image contains regions of interest (ROIs).
# Tr-me_0259.jpg: The image contains regions of interest (ROIs).
# Tr-me_0260.jpg: The image contains regions of interest (ROIs).
# Tr-me_0261.jpg: The image contains regions of interest (ROIs).
# Tr-me_0262.jpg: The image contains regions of interest (ROIs).
# Tr-me_0263.jpg: The image contains regions of interest (ROIs).
# Tr-me_0264.jpg: The image contains regions of interest (ROIs).
# Tr-me_0265.jpg: The image contains regions of interest (ROIs).
# Tr-me_0266.jpg: The image contains regions of interest (ROIs).
# Tr-me_0267.jpg: The image contains regions of interest (ROIs).
# Tr-me_0268.jpg: The image contains regions of interest (ROIs).
# Tr-me_0269.jpg: The image contains regions of interest (ROIs).
# Tr-me_0270.jpg: The image contains regions of interest (ROIs).
# Tr-me_0271.jpg: The image contains regions of interest (ROIs).
# Tr-me_0272.jpg: The image contains regions of interest (ROIs).
# Tr-me_0273.jpg: The image contains regions of interest (ROIs).
# Tr-me_0274.jpg: The image contains regions of interest (ROIs).
# Tr-me_0275.jpg: The image contains regions of interest (ROIs).
# Tr-me_0276.jpg: The image contains regions of interest (ROIs).
# Tr-me_0277.jpg: The image contains regions of interest (ROIs).
# Tr-me_0278.jpg: The image contains regions of interest (ROIs).
# Tr-me_0279.jpg: The image contains regions of interest (ROIs).
# Tr-me_0280.jpg: The image contains regions of interest (ROIs).
# Tr-me_0281.jpg: The image contains regions of interest (ROIs).
# Tr-me_0282.jpg: The image contains regions of interest (ROIs).
# Tr-me_0283.jpg: The image contains regions of interest (ROIs).
# Tr-me_0284.jpg: The image contains regions of interest (ROIs).
# Tr-me_0285.jpg: The image contains regions of interest (ROIs).
# Tr-me_0286.jpg: The image contains regions of interest (ROIs).
# Tr-me_0287.jpg: The image contains regions of interest (ROIs).
# Tr-me_0288.jpg: The image contains regions of interest (ROIs).
# Tr-me_0289.jpg: The image contains regions of interest (ROIs).
# Tr-me_0290.jpg: The image contains regions of interest (ROIs).
# Tr-me_0291.jpg: The image contains regions of interest (ROIs).
# Tr-me_0292.jpg: The image contains regions of interest (ROIs).
# Tr-me_0293.jpg: The image contains regions of interest (ROIs).
# Tr-me_0294.jpg: The image contains regions of interest (ROIs).
# Tr-me_0295.jpg: The image contains regions of interest (ROIs).
# Tr-me_0296.jpg: The image contains regions of interest (ROIs).
# Tr-me_0297.jpg: The image contains regions of interest (ROIs).
# Tr-me_0298.jpg: The image contains regions of interest (ROIs).
# Tr-me_0299.jpg: The image contains regions of interest (ROIs).
# Tr-me_0300.jpg: The image contains regions of interest (ROIs).
# Tr-me_0302.jpg: The image contains regions of interest (ROIs).
# Tr-me_0303.jpg: The image contains regions of interest (ROIs).
# Tr-me_0304.jpg: The image contains regions of interest (ROIs).
# Tr-me_0305.jpg: The image contains regions of interest (ROIs).
# Tr-me_0306.jpg: The image contains regions of interest (ROIs).
# Tr-me_0307.jpg: The image contains regions of interest (ROIs).
# Tr-me_0308.jpg: The image contains regions of interest (ROIs).
# Tr-me_0309.jpg: The image contains regions of interest (ROIs).
# Tr-me_0310.jpg: The image contains regions of interest (ROIs).
# Tr-me_0311.jpg: The image contains regions of interest (ROIs).
# Tr-me_0312.jpg: The image contains regions of interest (ROIs).
# Tr-me_0313.jpg: The image contains regions of interest (ROIs).
# Tr-me_0314.jpg: The image contains regions of interest (ROIs).
# Tr-me_0315.jpg: The image contains regions of interest (ROIs).
# Tr-me_0316.jpg: The image contains regions of interest (ROIs).
# Tr-me_0317.jpg: The image contains regions of interest (ROIs).
# Tr-me_0318.jpg: The image contains regions of interest (ROIs).
# Tr-me_0319.jpg: The image contains regions of interest (ROIs).
# Tr-me_0320.jpg: The image contains regions of interest (ROIs).
# Tr-me_0321.jpg: The image contains regions of interest (ROIs).
# Tr-me_0322.jpg: The image contains regions of interest (ROIs).
# Tr-me_0323.jpg: The image contains regions of interest (ROIs).
# Tr-me_0324.jpg: The image contains regions of interest (ROIs).
# Tr-me_0325.jpg: The image contains regions of interest (ROIs).
# Tr-me_0326.jpg: The image contains regions of interest (ROIs).
# Tr-me_0327.jpg: The image contains regions of interest (ROIs).
# Tr-me_0328.jpg: The image contains regions of interest (ROIs).
# Tr-me_0329.jpg: The image contains regions of interest (ROIs).
# Tr-me_0330.jpg: The image contains regions of interest (ROIs).
# Tr-me_0331.jpg: The image contains regions of interest (ROIs).
# Tr-me_0332.jpg: The image contains regions of interest (ROIs).
# Tr-me_0333.jpg: The image contains regions of interest (ROIs).
# Tr-me_0334.jpg: The image contains regions of interest (ROIs).
# Tr-me_0335.jpg: The image contains regions of interest (ROIs).
# Tr-me_0336.jpg: The image contains regions of interest (ROIs).
# Tr-me_0337.jpg: The image contains regions of interest (ROIs).
# Tr-me_0338.jpg: The image contains regions of interest (ROIs).
# Tr-me_0339.jpg: The image contains regions of interest (ROIs).
# Tr-me_0340.jpg: The image contains regions of interest (ROIs).
# Tr-me_0341.jpg: The image contains regions of interest (ROIs).
# Tr-me_0342.jpg: The image contains regions of interest (ROIs).
# Tr-me_0343.jpg: The image contains regions of interest (ROIs).
# Tr-me_0344.jpg: The image contains regions of interest (ROIs).
# Tr-me_0345.jpg: The image contains regions of interest (ROIs).
# Tr-me_0346.jpg: The image contains regions of interest (ROIs).
# Tr-me_0347.jpg: The image contains regions of interest (ROIs).
# Tr-me_0348.jpg: The image contains regions of interest (ROIs).
# Tr-me_0349.jpg: The image contains regions of interest (ROIs).
# Tr-me_0350.jpg: The image contains regions of interest (ROIs).
# Tr-me_0351.jpg: The image contains regions of interest (ROIs).
# Tr-me_0352.jpg: The image contains regions of interest (ROIs).
# Tr-me_0353.jpg: The image contains regions of interest (ROIs).
# Tr-me_0354.jpg: The image contains regions of interest (ROIs).
# Tr-me_0355.jpg: The image contains regions of interest (ROIs).
# Tr-me_0356.jpg: The image contains regions of interest (ROIs).
# Tr-me_0357.jpg: The image contains regions of interest (ROIs).
# Tr-me_0358.jpg: The image contains regions of interest (ROIs).
# Tr-me_0359.jpg: The image contains regions of interest (ROIs).
# Tr-me_0360.jpg: The image contains regions of interest (ROIs).
# Tr-me_0361.jpg: The image contains regions of interest (ROIs).
# Tr-me_0362.jpg: The image contains regions of interest (ROIs).
# Tr-me_0363.jpg: The image contains regions of interest (ROIs).
# Tr-me_0364.jpg: The image contains regions of interest (ROIs).
# Tr-me_0365.jpg: The image contains regions of interest (ROIs).
# Tr-me_0366.jpg: The image contains regions of interest (ROIs).
# Tr-me_0367.jpg: The image contains regions of interest (ROIs).
# Tr-me_0368.jpg: The image contains regions of interest (ROIs).
# Tr-me_0369.jpg: The image contains regions of interest (ROIs).
# Tr-me_0370.jpg: The image contains regions of interest (ROIs).
# Tr-me_0371.jpg: The image contains regions of interest (ROIs).
# Tr-me_0372.jpg: The image contains regions of interest (ROIs).
# Tr-me_0373.jpg: The image contains regions of interest (ROIs).
# Tr-me_0374.jpg: The image contains regions of interest (ROIs).
# Tr-me_0375.jpg: The image contains regions of interest (ROIs).
# Tr-me_0376.jpg: The image contains regions of interest (ROIs).
# Tr-me_0377.jpg: The image contains regions of interest (ROIs).
# Tr-me_0378.jpg: The image contains regions of interest (ROIs).
# Tr-me_0379.jpg: The image contains regions of interest (ROIs).
# Tr-me_0380.jpg: The image contains regions of interest (ROIs).
# Tr-me_0381.jpg: The image contains regions of interest (ROIs).
# Tr-me_0382.jpg: The image contains regions of interest (ROIs).
# Tr-me_0383.jpg: The image contains regions of interest (ROIs).
# Tr-me_0384.jpg: The image contains regions of interest (ROIs).
# Tr-me_0385.jpg: The image contains regions of interest (ROIs).
# Tr-me_0386.jpg: The image contains regions of interest (ROIs).
# Tr-me_0387.jpg: The image contains regions of interest (ROIs).
# Tr-me_0388.jpg: The image contains regions of interest (ROIs).
# Tr-me_0389.jpg: The image contains regions of interest (ROIs).
# Tr-me_0390.jpg: The image contains regions of interest (ROIs).
# Tr-me_0391.jpg: The image contains regions of interest (ROIs).
# Tr-me_0392.jpg: The image contains regions of interest (ROIs).
# Tr-me_0393.jpg: The image contains regions of interest (ROIs).
# Tr-me_0394.jpg: The image contains regions of interest (ROIs).
# Tr-me_0395.jpg: The image contains regions of interest (ROIs).
# Tr-me_0396.jpg: The image contains regions of interest (ROIs).
# Tr-me_0397.jpg: The image contains regions of interest (ROIs).
# Tr-me_0398.jpg: The image contains regions of interest (ROIs).
# Tr-me_0399.jpg: The image contains regions of interest (ROIs).
# Tr-me_0400.jpg: The image contains regions of interest (ROIs).
# Tr-me_0401.jpg: The image contains regions of interest (ROIs).
# Tr-me_0402.jpg: The image contains regions of interest (ROIs).
# Tr-me_0403.jpg: The image contains regions of interest (ROIs).
# Tr-me_0404.jpg: The image contains regions of interest (ROIs).
# Tr-me_0405.jpg: The image contains regions of interest (ROIs).
# Tr-me_0406.jpg: The image contains regions of interest (ROIs).
# Tr-me_0407.jpg: The image contains regions of interest (ROIs).
# Tr-me_0408.jpg: The image contains regions of interest (ROIs).
# Tr-me_0409.jpg: The image contains regions of interest (ROIs).
# Tr-me_0410.jpg: The image contains regions of interest (ROIs).
# Tr-me_0411.jpg: The image contains regions of interest (ROIs).
# Tr-me_0412.jpg: The image contains regions of interest (ROIs).
# Tr-me_0413.jpg: The image contains regions of interest (ROIs).
# Tr-me_0414.jpg: The image contains regions of interest (ROIs).
# Tr-me_0415.jpg: The image contains regions of interest (ROIs).
# Tr-me_0416.jpg: The image contains regions of interest (ROIs).
# Tr-me_0417.jpg: The image contains regions of interest (ROIs).
# Tr-me_0418.jpg: The image contains regions of interest (ROIs).
# Tr-me_0419.jpg: The image contains regions of interest (ROIs).
# Tr-me_0420.jpg: The image contains regions of interest (ROIs).
# Tr-me_0421.jpg: The image contains regions of interest (ROIs).
# Tr-me_0422.jpg: The image contains regions of interest (ROIs).
# Tr-me_0423.jpg: The image contains regions of interest (ROIs).
# Tr-me_0424.jpg: The image contains regions of interest (ROIs).
# Tr-me_0425.jpg: The image contains regions of interest (ROIs).
# Tr-me_0426.jpg: The image contains regions of interest (ROIs).
# Tr-me_0427.jpg: The image contains regions of interest (ROIs).
# Tr-me_0428.jpg: The image contains regions of interest (ROIs).
# Tr-me_0429.jpg: The image contains regions of interest (ROIs).
# Tr-me_0430.jpg: The image contains regions of interest (ROIs).
# Tr-me_0431.jpg: The image contains regions of interest (ROIs).
# Tr-me_0432.jpg: The image contains regions of interest (ROIs).
# Tr-me_0433.jpg: The image contains regions of interest (ROIs).
# Tr-me_0434.jpg: The image contains regions of interest (ROIs).
# Tr-me_0435.jpg: The image contains regions of interest (ROIs).
# Tr-me_0436.jpg: The image contains regions of interest (ROIs).
# Tr-me_0437.jpg: The image contains regions of interest (ROIs).
# Tr-me_0438.jpg: The image contains regions of interest (ROIs).
# Tr-me_0439.jpg: The image contains regions of interest (ROIs).
# Tr-me_0440.jpg: The image contains regions of interest (ROIs).
# Tr-me_0441.jpg: The image contains regions of interest (ROIs).
# Tr-me_0442.jpg: The image contains regions of interest (ROIs).
# Tr-me_0443.jpg: The image contains regions of interest (ROIs).
# Tr-me_0444.jpg: The image contains regions of interest (ROIs).
# Tr-me_0445.jpg: The image contains regions of interest (ROIs).
# Tr-me_0446.jpg: The image contains regions of interest (ROIs).
# Tr-me_0447.jpg: The image contains regions of interest (ROIs).
# Tr-me_0448.jpg: The image contains regions of interest (ROIs).
# Tr-me_0449.jpg: The image contains regions of interest (ROIs).
# Tr-me_0450.jpg: The image contains regions of interest (ROIs).
# Tr-me_0451.jpg: The image contains regions of interest (ROIs).
# Tr-me_0452.jpg: The image contains regions of interest (ROIs).
# Tr-me_0453.jpg: The image contains regions of interest (ROIs).
# Tr-me_0454.jpg: The image contains regions of interest (ROIs).
# Tr-me_0455.jpg: The image contains regions of interest (ROIs).
# Tr-me_0456.jpg: The image contains regions of interest (ROIs).
# Tr-me_0457.jpg: The image contains regions of interest (ROIs).
# Tr-me_0458.jpg: The image contains regions of interest (ROIs).
# Tr-me_0459.jpg: The image contains regions of interest (ROIs).
# Tr-me_0460.jpg: The image contains regions of interest (ROIs).
# Tr-me_0461.jpg: The image contains regions of interest (ROIs).
# Tr-me_0462.jpg: The image contains regions of interest (ROIs).
# Tr-me_0463.jpg: The image contains regions of interest (ROIs).
# Tr-me_0464.jpg: The image contains regions of interest (ROIs).
# Tr-me_0465.jpg: The image contains regions of interest (ROIs).
# Tr-me_0466.jpg: The image contains regions of interest (ROIs).
# Tr-me_0467.jpg: The image contains regions of interest (ROIs).
# Tr-me_0468.jpg: The image contains regions of interest (ROIs).
# Tr-me_0469.jpg: The image contains regions of interest (ROIs).
# Tr-me_0470.jpg: The image contains regions of interest (ROIs).
# Tr-me_0471.jpg: The image contains regions of interest (ROIs).
# Tr-me_0472.jpg: The image contains regions of interest (ROIs).
# Tr-me_0473.jpg: The image contains regions of interest (ROIs).
# Tr-me_0474.jpg: The image contains regions of interest (ROIs).
# Tr-me_0475.jpg: The image contains regions of interest (ROIs).
# Tr-me_0476.jpg: The image contains regions of interest (ROIs).
# Tr-me_0477.jpg: The image contains regions of interest (ROIs).
# Tr-me_0478.jpg: The image contains regions of interest (ROIs).
# Tr-me_0479.jpg: The image contains regions of interest (ROIs).
# Tr-me_0480.jpg: The image contains regions of interest (ROIs).
# Tr-me_0481.jpg: The image contains regions of interest (ROIs).
# Tr-me_0482.jpg: The image contains regions of interest (ROIs).
# Tr-me_0483.jpg: The image contains regions of interest (ROIs).
# Tr-me_0484.jpg: The image contains regions of interest (ROIs).
# Tr-me_0485.jpg: The image contains regions of interest (ROIs).
# Tr-me_0486.jpg: The image contains regions of interest (ROIs).
# Tr-me_0487.jpg: The image contains regions of interest (ROIs).
# Tr-me_0488.jpg: The image contains regions of interest (ROIs).
# Tr-me_0489.jpg: The image contains regions of interest (ROIs).
# Tr-me_0490.jpg: The image contains regions of interest (ROIs).
# Tr-me_0491.jpg: The image contains regions of interest (ROIs).
# Tr-me_0492.jpg: The image contains regions of interest (ROIs).
# Tr-me_0493.jpg: The image contains regions of interest (ROIs).
# Tr-me_0494.jpg: The image contains regions of interest (ROIs).
# Tr-me_0495.jpg: The image contains regions of interest (ROIs).
# Tr-me_0496.jpg: The image contains regions of interest (ROIs).
# Tr-me_0497.jpg: The image contains regions of interest (ROIs).
# Tr-me_0498.jpg: The image contains regions of interest (ROIs).
# Tr-me_0499.jpg: The image contains regions of interest (ROIs).
# Tr-me_0500.jpg: The image contains regions of interest (ROIs).
# Tr-me_0501.jpg: The image contains regions of interest (ROIs).
# Tr-me_0502.jpg: The image contains regions of interest (ROIs).
# Tr-me_0503.jpg: The image contains regions of interest (ROIs).
# Tr-me_0504.jpg: The image contains regions of interest (ROIs).
# Tr-me_0505.jpg: The image contains regions of interest (ROIs).
# Tr-me_0506.jpg: The image contains regions of interest (ROIs).
# Tr-me_0507.jpg: The image contains regions of interest (ROIs).
# Tr-me_0508.jpg: The image contains regions of interest (ROIs).
# Tr-me_0509.jpg: The image contains regions of interest (ROIs).
# Tr-me_0510.jpg: The image contains regions of interest (ROIs).
# Tr-me_0511.jpg: The image contains regions of interest (ROIs).
# Tr-me_0512.jpg: The image contains regions of interest (ROIs).
# Tr-me_0513.jpg: The image contains regions of interest (ROIs).
# Tr-me_0514.jpg: The image contains regions of interest (ROIs).
# Tr-me_0515.jpg: The image contains regions of interest (ROIs).
# Tr-me_0516.jpg: The image contains regions of interest (ROIs).
# Tr-me_0517.jpg: The image contains regions of interest (ROIs).
# Tr-me_0518.jpg: The image contains regions of interest (ROIs).
# Tr-me_0519.jpg: The image contains regions of interest (ROIs).
# Tr-me_0520.jpg: The image contains regions of interest (ROIs).
# Tr-me_0521.jpg: The image contains regions of interest (ROIs).
# Tr-me_0522.jpg: The image contains regions of interest (ROIs).
# Tr-me_0523.jpg: The image contains regions of interest (ROIs).
# Tr-me_0524.jpg: The image contains regions of interest (ROIs).
# Tr-me_0525.jpg: The image contains regions of interest (ROIs).
# Tr-me_0526.jpg: The image contains regions of interest (ROIs).
# Tr-me_0527.jpg: The image contains regions of interest (ROIs).
# Tr-me_0528.jpg: The image contains regions of interest (ROIs).
# Tr-me_0529.jpg: The image contains regions of interest (ROIs).
# Tr-me_0530.jpg: The image contains regions of interest (ROIs).
# Tr-me_0531.jpg: The image contains regions of interest (ROIs).
# Tr-me_0532.jpg: The image contains regions of interest (ROIs).
# Tr-me_0533.jpg: The image contains regions of interest (ROIs).
# Tr-me_0534.jpg: The image contains regions of interest (ROIs).
# Tr-me_0535.jpg: The image contains regions of interest (ROIs).
# Tr-me_0536.jpg: The image contains regions of interest (ROIs).
# Tr-me_0537.jpg: The image contains regions of interest (ROIs).
# Tr-me_0538.jpg: The image contains regions of interest (ROIs).
# Tr-me_0539.jpg: The image contains regions of interest (ROIs).
# Tr-me_0540.jpg: The image contains regions of interest (ROIs).
# Tr-me_0541.jpg: The image contains regions of interest (ROIs).
# Tr-me_0542.jpg: The image contains regions of interest (ROIs).
# Tr-me_0543.jpg: The image contains regions of interest (ROIs).
# Tr-me_0544.jpg: The image contains regions of interest (ROIs).
# Tr-me_0545.jpg: The image contains regions of interest (ROIs).
# Tr-me_0546.jpg: The image contains regions of interest (ROIs).
# Tr-me_0547.jpg: The image contains regions of interest (ROIs).
# Tr-me_0548.jpg: The image contains regions of interest (ROIs).
# Tr-me_0549.jpg: The image contains regions of interest (ROIs).
# Tr-me_0550.jpg: The image contains regions of interest (ROIs).
# Tr-me_0551.jpg: The image contains regions of interest (ROIs).
# Tr-me_0552.jpg: The image contains regions of interest (ROIs).
# Tr-me_0553.jpg: The image contains regions of interest (ROIs).
# Tr-me_0554.jpg: The image contains regions of interest (ROIs).
# Tr-me_0555.jpg: The image contains regions of interest (ROIs).
# Tr-me_0556.jpg: The image contains regions of interest (ROIs).
# Tr-me_0557.jpg: The image contains regions of interest (ROIs).
# Tr-me_0558.jpg: The image contains regions of interest (ROIs).
# Tr-me_0559.jpg: The image contains regions of interest (ROIs).
# Tr-me_0560.jpg: The image contains regions of interest (ROIs).
# Tr-me_0561.jpg: The image contains regions of interest (ROIs).
# Tr-me_0562.jpg: The image contains regions of interest (ROIs).
# Tr-me_0563.jpg: The image contains regions of interest (ROIs).
# Tr-me_0564.jpg: The image contains regions of interest (ROIs).
# Tr-me_0565.jpg: The image contains regions of interest (ROIs).
# Tr-me_0566.jpg: The image contains regions of interest (ROIs).
# Tr-me_0567.jpg: The image contains regions of interest (ROIs).
# Tr-me_0568.jpg: The image contains regions of interest (ROIs).
# Tr-me_0569.jpg: The image contains regions of interest (ROIs).
# Tr-me_0570.jpg: The image contains regions of interest (ROIs).
# Tr-me_0571.jpg: The image contains regions of interest (ROIs).
# Tr-me_0572.jpg: The image contains regions of interest (ROIs).
# Tr-me_0573.jpg: The image contains regions of interest (ROIs).
# Tr-me_0574.jpg: The image contains regions of interest (ROIs).
# Tr-me_0575.jpg: The image contains regions of interest (ROIs).
# Tr-me_0576.jpg: The image contains regions of interest (ROIs).
# Tr-me_0577.jpg: The image contains regions of interest (ROIs).
# Tr-me_0578.jpg: The image contains regions of interest (ROIs).
# Tr-me_0579.jpg: The image contains regions of interest (ROIs).
# Tr-me_0580.jpg: The image contains regions of interest (ROIs).
# Tr-me_0581.jpg: The image contains regions of interest (ROIs).
# Tr-me_0582.jpg: The image contains regions of interest (ROIs).
# Tr-me_0583.jpg: The image contains regions of interest (ROIs).
# Tr-me_0584.jpg: The image contains regions of interest (ROIs).
# Tr-me_0585.jpg: The image contains regions of interest (ROIs).
# Tr-me_0586.jpg: The image contains regions of interest (ROIs).
# Tr-me_0587.jpg: The image contains regions of interest (ROIs).
# Tr-me_0588.jpg: The image contains regions of interest (ROIs).
# Tr-me_0589.jpg: The image contains regions of interest (ROIs).
# Tr-me_0590.jpg: The image contains regions of interest (ROIs).
# Tr-me_0591.jpg: The image contains regions of interest (ROIs).
# Tr-me_0592.jpg: The image contains regions of interest (ROIs).
# Tr-me_0593.jpg: The image contains regions of interest (ROIs).
# Tr-me_0594.jpg: The image contains regions of interest (ROIs).
# Tr-me_0595.jpg: The image contains regions of interest (ROIs).
# Tr-me_0596.jpg: The image contains regions of interest (ROIs).
# Tr-me_0597.jpg: The image contains regions of interest (ROIs).
# Tr-me_0598.jpg: The image contains regions of interest (ROIs).
# Tr-me_0599.jpg: The image contains regions of interest (ROIs).
# Tr-me_0600.jpg: The image contains regions of interest (ROIs).
# Tr-me_0601.jpg: The image contains regions of interest (ROIs).
# Tr-me_0602.jpg: The image contains regions of interest (ROIs).
# Tr-me_0603.jpg: The image contains regions of interest (ROIs).
# Tr-me_0604.jpg: The image contains regions of interest (ROIs).
# Tr-me_0605.jpg: The image contains regions of interest (ROIs).
# Tr-me_0606.jpg: The image contains regions of interest (ROIs).
# Tr-me_0608.jpg: The image contains regions of interest (ROIs).
# Tr-me_0609.jpg: The image contains regions of interest (ROIs).
# Tr-me_0610.jpg: The image contains regions of interest (ROIs).
# Tr-me_0611.jpg: The image contains regions of interest (ROIs).
# Tr-me_0612.jpg: The image contains regions of interest (ROIs).
# Tr-me_0613.jpg: The image contains regions of interest (ROIs).
# Tr-me_0614.jpg: The image contains regions of interest (ROIs).
# Tr-me_0615.jpg: The image contains regions of interest (ROIs).
# Tr-me_0616.jpg: The image contains regions of interest (ROIs).
# Tr-me_0617.jpg: The image contains regions of interest (ROIs).
# Tr-me_0618.jpg: The image contains regions of interest (ROIs).
# Tr-me_0619.jpg: The image contains regions of interest (ROIs).
# Tr-me_0620.jpg: The image contains regions of interest (ROIs).
# Tr-me_0621.jpg: The image contains regions of interest (ROIs).
# Tr-me_0622.jpg: The image contains regions of interest (ROIs).
# Tr-me_0623.jpg: The image contains regions of interest (ROIs).
# Tr-me_0624.jpg: The image contains regions of interest (ROIs).
# Tr-me_0625.jpg: The image contains regions of interest (ROIs).
# Tr-me_0626.jpg: The image contains regions of interest (ROIs).
# Tr-me_0627.jpg: The image contains regions of interest (ROIs).
# Tr-me_0628.jpg: The image contains regions of interest (ROIs).
# Tr-me_0629.jpg: The image contains regions of interest (ROIs).
# Tr-me_0630.jpg: The image contains regions of interest (ROIs).
# Tr-me_0631.jpg: The image contains regions of interest (ROIs).
# Tr-me_0632.jpg: The image contains regions of interest (ROIs).
# Tr-me_0633.jpg: The image contains regions of interest (ROIs).
# Tr-me_0634.jpg: The image contains regions of interest (ROIs).
# Tr-me_0635.jpg: The image contains regions of interest (ROIs).
# Tr-me_0636.jpg: The image contains regions of interest (ROIs).
# Tr-me_0637.jpg: The image contains regions of interest (ROIs).
# Tr-me_0638.jpg: The image contains regions of interest (ROIs).
# Tr-me_0639.jpg: The image contains regions of interest (ROIs).
# Tr-me_0640.jpg: The image contains regions of interest (ROIs).
# Tr-me_0641.jpg: The image contains regions of interest (ROIs).
# Tr-me_0642.jpg: The image contains regions of interest (ROIs).
# Tr-me_0643.jpg: The image contains regions of interest (ROIs).
# Tr-me_0644.jpg: The image contains regions of interest (ROIs).
# Tr-me_0645.jpg: The image contains regions of interest (ROIs).
# Tr-me_0646.jpg: The image contains regions of interest (ROIs).
# Tr-me_0647.jpg: The image contains regions of interest (ROIs).
# Tr-me_0648.jpg: The image contains regions of interest (ROIs).
# Tr-me_0649.jpg: The image contains regions of interest (ROIs).
# Tr-me_0650.jpg: The image contains regions of interest (ROIs).
# Tr-me_0651.jpg: The image contains regions of interest (ROIs).
# Tr-me_0652.jpg: The image contains regions of interest (ROIs).
# Tr-me_0653.jpg: The image contains regions of interest (ROIs).
# Tr-me_0654.jpg: The image contains regions of interest (ROIs).
# Tr-me_0655.jpg: The image contains regions of interest (ROIs).
# Tr-me_0656.jpg: The image contains regions of interest (ROIs).
# Tr-me_0657.jpg: The image contains regions of interest (ROIs).
# Tr-me_0658.jpg: The image contains regions of interest (ROIs).
# Tr-me_0659.jpg: The image contains regions of interest (ROIs).
# Tr-me_0660.jpg: The image contains regions of interest (ROIs).
# Tr-me_0661.jpg: The image contains regions of interest (ROIs).
# Tr-me_0662.jpg: The image contains regions of interest (ROIs).
# Tr-me_0663.jpg: The image contains regions of interest (ROIs).
# Tr-me_0664.jpg: The image contains regions of interest (ROIs).
# Tr-me_0665.jpg: The image contains regions of interest (ROIs).
# Tr-me_0666.jpg: The image contains regions of interest (ROIs).
# Tr-me_0667.jpg: The image contains regions of interest (ROIs).
# Tr-me_0668.jpg: The image contains regions of interest (ROIs).
# Tr-me_0669.jpg: The image contains regions of interest (ROIs).
# Tr-me_0670.jpg: The image contains regions of interest (ROIs).
# Tr-me_0671.jpg: The image contains regions of interest (ROIs).
# Tr-me_0672.jpg: The image contains regions of interest (ROIs).
# Tr-me_0673.jpg: The image contains regions of interest (ROIs).
# Tr-me_0674.jpg: The image contains regions of interest (ROIs).
# Tr-me_0675.jpg: The image contains regions of interest (ROIs).
# Tr-me_0676.jpg: The image contains regions of interest (ROIs).
# Tr-me_0677.jpg: The image contains regions of interest (ROIs).
# Tr-me_0678.jpg: The image contains regions of interest (ROIs).
# Tr-me_0679.jpg: The image contains regions of interest (ROIs).
# Tr-me_0680.jpg: The image contains regions of interest (ROIs).
# Tr-me_0681.jpg: The image contains regions of interest (ROIs).
# Tr-me_0682.jpg: The image contains regions of interest (ROIs).
# Tr-me_0683.jpg: The image contains regions of interest (ROIs).
# Tr-me_0684.jpg: The image contains regions of interest (ROIs).
# Tr-me_0685.jpg: The image contains regions of interest (ROIs).
# Tr-me_0686.jpg: The image contains regions of interest (ROIs).
# Tr-me_0687.jpg: The image contains regions of interest (ROIs).
# Tr-me_0688.jpg: The image contains regions of interest (ROIs).
# Tr-me_0689.jpg: The image contains regions of interest (ROIs).
# Tr-me_0690.jpg: The image contains regions of interest (ROIs).
# Tr-me_0691.jpg: The image contains regions of interest (ROIs).
# Tr-me_0692.jpg: The image contains regions of interest (ROIs).
# Tr-me_0693.jpg: The image contains regions of interest (ROIs).
# Tr-me_0694.jpg: The image contains regions of interest (ROIs).
# Tr-me_0695.jpg: The image contains regions of interest (ROIs).
# Tr-me_0696.jpg: The image contains regions of interest (ROIs).
# Tr-me_0697.jpg: The image contains regions of interest (ROIs).
# Tr-me_0698.jpg: The image contains regions of interest (ROIs).
# Tr-me_0699.jpg: The image contains regions of interest (ROIs).
# Tr-me_0700.jpg: The image contains regions of interest (ROIs).
# Tr-me_0701.jpg: The image contains regions of interest (ROIs).
# Tr-me_0702.jpg: The image contains regions of interest (ROIs).
# Tr-me_0703.jpg: The image contains regions of interest (ROIs).
# Tr-me_0704.jpg: The image contains regions of interest (ROIs).
# Tr-me_0705.jpg: The image contains regions of interest (ROIs).
# Tr-me_0706.jpg: The image contains regions of interest (ROIs).
# Tr-me_0707.jpg: The image contains regions of interest (ROIs).
# Tr-me_0708.jpg: The image contains regions of interest (ROIs).
# Tr-me_0709.jpg: The image contains regions of interest (ROIs).
# Tr-me_0710.jpg: The image contains regions of interest (ROIs).
# Tr-me_0711.jpg: The image contains regions of interest (ROIs).
# Tr-me_0712.jpg: The image contains regions of interest (ROIs).
# Tr-me_0713.jpg: The image contains regions of interest (ROIs).
# Tr-me_0714.jpg: The image contains regions of interest (ROIs).
# Tr-me_0715.jpg: The image contains regions of interest (ROIs).
# Tr-me_0716.jpg: The image contains regions of interest (ROIs).
# Tr-me_0717.jpg: The image contains regions of interest (ROIs).
# Tr-me_0718.jpg: The image contains regions of interest (ROIs).
# Tr-me_0719.jpg: The image contains regions of interest (ROIs).
# Tr-me_0720.jpg: The image contains regions of interest (ROIs).
# Tr-me_0721.jpg: The image contains regions of interest (ROIs).
# Tr-me_0722.jpg: The image contains regions of interest (ROIs).
# Tr-me_0723.jpg: The image contains regions of interest (ROIs).
# Tr-me_0724.jpg: The image contains regions of interest (ROIs).
# Tr-me_0725.jpg: The image contains regions of interest (ROIs).
# Tr-me_0726.jpg: The image contains regions of interest (ROIs).
# Tr-me_0727.jpg: The image contains regions of interest (ROIs).
# Tr-me_0728.jpg: The image contains regions of interest (ROIs).
# Tr-me_0729.jpg: The image contains regions of interest (ROIs).
# Tr-me_0730.jpg: The image contains regions of interest (ROIs).
# Tr-me_0731.jpg: The image contains regions of interest (ROIs).
# Tr-me_0732.jpg: The image contains regions of interest (ROIs).
# Tr-me_0733.jpg: The image contains regions of interest (ROIs).
# Tr-me_0734.jpg: The image contains regions of interest (ROIs).
# Tr-me_0735.jpg: The image contains regions of interest (ROIs).
# Tr-me_0736.jpg: The image contains regions of interest (ROIs).
# Tr-me_0737.jpg: The image contains regions of interest (ROIs).
# Tr-me_0738.jpg: The image contains regions of interest (ROIs).
# Tr-me_0739.jpg: The image contains regions of interest (ROIs).
# Tr-me_0740.jpg: The image contains regions of interest (ROIs).
# Tr-me_0741.jpg: The image contains regions of interest (ROIs).
# Tr-me_0742.jpg: The image contains regions of interest (ROIs).
# Tr-me_0743.jpg: The image contains regions of interest (ROIs).
# Tr-me_0744.jpg: The image contains regions of interest (ROIs).
# Tr-me_0745.jpg: The image contains regions of interest (ROIs).
# Tr-me_0746.jpg: The image contains regions of interest (ROIs).
# Tr-me_0747.jpg: The image contains regions of interest (ROIs).
# Tr-me_0748.jpg: The image contains regions of interest (ROIs).
# Tr-me_0749.jpg: The image contains regions of interest (ROIs).
# Tr-me_0750.jpg: The image contains regions of interest (ROIs).
# Tr-me_0751.jpg: The image contains regions of interest (ROIs).
# Tr-me_0752.jpg: The image contains regions of interest (ROIs).
# Tr-me_0753.jpg: The image contains regions of interest (ROIs).
# Tr-me_0754.jpg: The image contains regions of interest (ROIs).
# Tr-me_0755.jpg: The image contains regions of interest (ROIs).
# Tr-me_0756.jpg: The image contains regions of interest (ROIs).
# Tr-me_0757.jpg: The image contains regions of interest (ROIs).
# Tr-me_0758.jpg: The image contains regions of interest (ROIs).
# Tr-me_0759.jpg: The image contains regions of interest (ROIs).
# Tr-me_0760.jpg: The image contains regions of interest (ROIs).
# Tr-me_0761.jpg: The image contains regions of interest (ROIs).
# Tr-me_0762.jpg: The image contains regions of interest (ROIs).
# ...
# Tr-me_1086.jpg: The image contains regions of interest (ROIs).
# Tr-me_1087.jpg: The image contains regions of interest (ROIs).
# Tr-me_1088.jpg: The image contains regions of interest (ROIs).
# Tr-me_1089.jpg: The image contains regions of interest (ROIs).
# Tr-me_1090.jpg: The image contains regions of interest (ROIs).
# Tr-me_1091.jpg: The image contains regions of interest (ROIs).
# Tr-me_1092.jpg: The image contains regions of interest (ROIs).
# Tr-me_1093.jpg: The image contains regions of interest (ROIs).
# Tr-me_1094.jpg: The image contains regions of interest (ROIs).
# Tr-me_1095.jpg: The image contains regions of interest (ROIs).
# Tr-me_1096.jpg: The image contains regions of interest (ROIs).
# Tr-me_1097.jpg: The image contains regions of interest (ROIs).
# Tr-me_1098.jpg: The image contains regions of interest (ROIs).
# Tr-me_1099.jpg: The image contains regions of interest (ROIs).
# Tr-me_1100.jpg: The image contains regions of interest (ROIs).
# Tr-me_1101.jpg: The image contains regions of interest (ROIs).
# Tr-me_1102.jpg: The image contains regions of interest (ROIs).
# Tr-me_1103.jpg: The image contains regions of interest (ROIs).
# Tr-me_1104.jpg: The image contains regions of interest (ROIs).
# Tr-me_1105.jpg: The image contains regions of interest (ROIs).
# Tr-me_1106.jpg: The image contains regions of interest (ROIs).
# Tr-me_1107.jpg: The image contains regions of interest (ROIs).
# Tr-me_1108.jpg: The image contains regions of interest (ROIs).
# Tr-me_1109.jpg: The image contains regions of interest (ROIs).
# Tr-me_1110.jpg: The image contains regions of interest (ROIs).
# Tr-me_1111.jpg: The image contains regions of interest (ROIs).
# Tr-me_1112.jpg: The image contains regions of interest (ROIs).
# Tr-me_1113.jpg: The image contains regions of interest (ROIs).
# Tr-me_1114.jpg: The image contains regions of interest (ROIs).
# Tr-me_1115.jpg: The image contains regions of interest (ROIs).
# Tr-me_1116.jpg: The image contains regions of interest (ROIs).
# Tr-me_1117.jpg: The image contains regions of interest (ROIs).
# Tr-me_1118.jpg: The image contains regions of interest (ROIs).
# Tr-me_1119.jpg: The image contains regions of interest (ROIs).
# Tr-me_1120.jpg: The image contains regions of interest (ROIs).
# Tr-me_1121.jpg: The image contains regions of interest (ROIs).
# Tr-me_1122.jpg: The image contains regions of interest (ROIs).
# Tr-me_1123.jpg: The image contains regions of interest (ROIs).
# Tr-me_1124.jpg: The image contains regions of interest (ROIs).
# Tr-me_1125.jpg: The image contains regions of interest (ROIs).
# Tr-me_1126.jpg: The image contains regions of interest (ROIs).
# Tr-me_1127.jpg: The image contains regions of interest (ROIs).
# Tr-me_1128.jpg: The image contains regions of interest (ROIs).
# Tr-me_1129.jpg: The image contains regions of interest (ROIs).
# Tr-me_1130.jpg: The image contains regions of interest (ROIs).
# Tr-me_1131.jpg: The image contains regions of interest (ROIs).
# Tr-me_1132.jpg: The image contains regions of interest (ROIs).
# Tr-me_1133.jpg: The image contains regions of interest (ROIs).
# Tr-me_1134.jpg: The image contains regions of interest (ROIs).
# Tr-me_1135.jpg: The image contains regions of interest (ROIs).
# Tr-me_1136.jpg: The image contains regions of interest (ROIs).
# Tr-me_1137.jpg: The image contains regions of interest (ROIs).
# Tr-me_1138.jpg: The image contains regions of interest (ROIs).
# Tr-me_1139.jpg: The image contains regions of interest (ROIs).
# Tr-me_1140.jpg: The image contains regions of interest (ROIs).
# Tr-me_1141.jpg: The image contains regions of interest (ROIs).
# Tr-me_1142.jpg: The image contains regions of interest (ROIs).
# Tr-me_1143.jpg: The image contains regions of interest (ROIs).
# Tr-me_1144.jpg: The image contains regions of interest (ROIs).
# Tr-me_1145.jpg: The image contains regions of interest (ROIs).
# Tr-me_1146.jpg: The image contains regions of interest (ROIs).
# Tr-me_1147.jpg: The image contains regions of interest (ROIs).
# Tr-me_1148.jpg: The image contains regions of interest (ROIs).
# Tr-me_1149.jpg: The image contains regions of interest (ROIs).
# Tr-me_1150.jpg: The image contains regions of interest (ROIs).
# Tr-me_1151.jpg: The image contains regions of interest (ROIs).
# Tr-me_1152.jpg: The image contains regions of interest (ROIs).
# Tr-me_1153.jpg: The image contains regions of interest (ROIs).
# Tr-me_1154.jpg: The image contains regions of interest (ROIs).
# Tr-me_1155.jpg: The image contains regions of interest (ROIs).
# Tr-me_1156.jpg: The image contains regions of interest (ROIs).
# Tr-me_1157.jpg: The image contains regions of interest (ROIs).
# Tr-me_1158.jpg: The image contains regions of interest (ROIs).
# Tr-me_1159.jpg: The image contains regions of interest (ROIs).
# Tr-me_1160.jpg: The image contains regions of interest (ROIs).
# Tr-me_1161.jpg: The image contains regions of interest (ROIs).
# Tr-me_1162.jpg: The image contains regions of interest (ROIs).
# Tr-me_1163.jpg: The image contains regions of interest (ROIs).
# Tr-me_1164.jpg: The image contains regions of interest (ROIs).
# Tr-me_1165.jpg: The image contains regions of interest (ROIs).
# Tr-me_1166.jpg: The image contains regions of interest (ROIs).
# Tr-me_1167.jpg: The image contains regions of interest (ROIs).
# Tr-me_1168.jpg: The image contains regions of interest (ROIs).
# Tr-me_1169.jpg: The image contains regions of interest (ROIs).
# Tr-me_1170.jpg: The image contains regions of interest (ROIs).
# Tr-me_1171.jpg: The image contains regions of interest (ROIs).
# Tr-me_1172.jpg: The image contains regions of interest (ROIs).
# Tr-me_1173.jpg: The image contains regions of interest (ROIs).
# Tr-me_1174.jpg: The image contains regions of interest (ROIs).
# Tr-me_1175.jpg: The image contains regions of interest (ROIs).
# Tr-me_1176.jpg: The image contains regions of interest (ROIs).
# Tr-me_1177.jpg: The image contains regions of interest (ROIs).
# Tr-me_1178.jpg: The image contains regions of interest (ROIs).
# Tr-me_1179.jpg: The image contains regions of interest (ROIs).
# Tr-me_1180.jpg: The image contains regions of interest (ROIs).
# Tr-me_1181.jpg: The image contains regions of interest (ROIs).
# Tr-me_1182.jpg: The image contains regions of interest (ROIs).
# Tr-me_1183.jpg: The image contains regions of interest (ROIs).
# Tr-me_1184.jpg: The image contains regions of interest (ROIs).
# Tr-me_1185.jpg: The image contains regions of interest (ROIs).
# Tr-me_1186.jpg: The image contains regions of interest (ROIs).
# Tr-me_1187.jpg: The image contains regions of interest (ROIs).
# Tr-me_1188.jpg: The image contains regions of interest (ROIs).
# Tr-me_1189.jpg: The image contains regions of interest (ROIs).
# Tr-me_1190.jpg: The image contains regions of interest (ROIs).
# Tr-me_1191.jpg: The image contains regions of interest (ROIs).
# Tr-me_1192.jpg: The image contains regions of interest (ROIs).
# Tr-me_1193.jpg: The image contains regions of interest (ROIs).
# Tr-me_1194.jpg: The image contains regions of interest (ROIs).
# Tr-me_1195.jpg: The image contains regions of interest (ROIs).
# Tr-me_1196.jpg: The image contains regions of interest (ROIs).
# Tr-me_1197.jpg: The image contains regions of interest (ROIs).
# Tr-me_1198.jpg: The image contains regions of interest (ROIs).
# Tr-me_1199.jpg: The image contains regions of interest (ROIs).
# Tr-me_1200.jpg: The image contains regions of interest (ROIs).
# Tr-me_1201.jpg: The image contains regions of interest (ROIs).
# Tr-me_1202.jpg: The image contains regions of interest (ROIs).
# Tr-me_1203.jpg: The image contains regions of interest (ROIs).
# Tr-me_1204.jpg: The image contains regions of interest (ROIs).
# Tr-me_1205.jpg: The image contains regions of interest (ROIs).
# Tr-me_1206.jpg: The image contains regions of interest (ROIs).
# Tr-me_1207.jpg: The image contains regions of interest (ROIs).
# Tr-me_1208.jpg: The image contains regions of interest (ROIs).
# Tr-me_1209.jpg: The image contains regions of interest (ROIs).
# Tr-me_1210.jpg: The image contains regions of interest (ROIs).
# Tr-me_1211.jpg: The image contains regions of interest (ROIs).
# Tr-me_1212.jpg: The image contains regions of interest (ROIs).
# Tr-me_1213.jpg: The image contains regions of interest (ROIs).
# Tr-me_1214.jpg: The image contains regions of interest (ROIs).
# Tr-me_1215.jpg: The image contains regions of interest (ROIs).
# Tr-me_1216.jpg: The image contains regions of interest (ROIs).
# Tr-me_1217.jpg: The image contains regions of interest (ROIs).
# Tr-me_1218.jpg: The image contains regions of interest (ROIs).
# Tr-me_1219.jpg: The image contains regions of interest (ROIs).
# Tr-me_1220.jpg: The image contains regions of interest (ROIs).
# Tr-me_1221.jpg: The image contains regions of interest (ROIs).
# Tr-me_1222.jpg: The image contains regions of interest (ROIs).
# Tr-me_1223.jpg: The image contains regions of interest (ROIs).
# Tr-me_1224.jpg: The image contains regions of interest (ROIs).
# Tr-me_1225.jpg: The image contains regions of interest (ROIs).
# Tr-me_1226.jpg: The image contains regions of interest (ROIs).
# Tr-me_1227.jpg: The image contains regions of interest (ROIs).
# Tr-me_1228.jpg: The image contains regions of interest (ROIs).
# Tr-me_1229.jpg: The image contains regions of interest (ROIs).
# Tr-me_1230.jpg: The image contains regions of interest (ROIs).
# Tr-me_1231.jpg: The image contains regions of interest (ROIs).
# Tr-me_1232.jpg: The image contains regions of interest (ROIs).
# Tr-me_1233.jpg: The image contains regions of interest (ROIs).
# Tr-me_1234.jpg: The image contains regions of interest (ROIs).
# Tr-me_1235.jpg: The image contains regions of interest (ROIs).
# Tr-me_1236.jpg: The image contains regions of interest (ROIs).
# Tr-me_1237.jpg: The image contains regions of interest (ROIs).
# Tr-me_1238.jpg: The image contains regions of interest (ROIs).
# Tr-me_1239.jpg: The image contains regions of interest (ROIs).
# Tr-me_1240.jpg: The image contains regions of interest (ROIs).
# Tr-me_1241.jpg: The image contains regions of interest (ROIs).
# Tr-me_1242.jpg: The image contains regions of interest (ROIs).
# Tr-me_1243.jpg: The image contains regions of interest (ROIs).
# Tr-me_1244.jpg: The image contains regions of interest (ROIs).
# Tr-me_1245.jpg: The image contains regions of interest (ROIs).
# Tr-me_1246.jpg: The image contains regions of interest (ROIs).
# Tr-me_1247.jpg: The image contains regions of interest (ROIs).
# Tr-me_1248.jpg: The image contains regions of interest (ROIs).
# Tr-me_1249.jpg: The image contains regions of interest (ROIs).
# Tr-me_1250.jpg: The image contains regions of interest (ROIs).
# Tr-me_1251.jpg: The image contains regions of interest (ROIs).
# Tr-me_1252.jpg: The image contains regions of interest (ROIs).
# Tr-me_1253.jpg: The image contains regions of interest (ROIs).
# Tr-me_1254.jpg: The image contains regions of interest (ROIs).
# Tr-me_1255.jpg: The image contains regions of interest (ROIs).
# Tr-me_1256.jpg: The image contains regions of interest (ROIs).
# Tr-me_1257.jpg: The image contains regions of interest (ROIs).
# Tr-me_1258.jpg: The image contains regions of interest (ROIs).
# Tr-me_1259.jpg: The image contains regions of interest (ROIs).
# Tr-me_1260.jpg: The image contains regions of interest (ROIs).
# Tr-me_1261.jpg: The image contains regions of interest (ROIs).
# Tr-me_1262.jpg: The image contains regions of interest (ROIs).
# Tr-me_1263.jpg: The image contains regions of interest (ROIs).
# Tr-me_1264.jpg: The image contains regions of interest (ROIs).
# Tr-me_1265.jpg: The image contains regions of interest (ROIs).
# Tr-me_1266.jpg: The image contains regions of interest (ROIs).
# Tr-me_1267.jpg: The image contains regions of interest (ROIs).
# Tr-me_1268.jpg: The image contains regions of interest (ROIs).
# Tr-me_1269.jpg: The image contains regions of interest (ROIs).
# Tr-me_1270.jpg: The image contains regions of interest (ROIs).
# Tr-me_1271.jpg: The image contains regions of interest (ROIs).
# Tr-me_1272.jpg: The image contains regions of interest (ROIs).
# Tr-me_1273.jpg: The image contains regions of interest (ROIs).
# Tr-me_1274.jpg: The image contains regions of interest (ROIs).
# Tr-me_1275.jpg: The image contains regions of interest (ROIs).
# Tr-me_1276.jpg: The image contains regions of interest (ROIs).
# Tr-me_1277.jpg: The image contains regions of interest (ROIs).
# Tr-me_1278.jpg: The image contains regions of interest (ROIs).
# Tr-me_1279.jpg: The image contains regions of interest (ROIs).
# Tr-me_1280.jpg: The image contains regions of interest (ROIs).
# Tr-me_1281.jpg: The image contains regions of interest (ROIs).
# Tr-me_1282.jpg: The image contains regions of interest (ROIs).
# Tr-me_1283.jpg: The image contains regions of interest (ROIs).
# Tr-me_1284.jpg: The image contains regions of interest (ROIs).
# Tr-me_1285.jpg: The image contains regions of interest (ROIs).
# Tr-me_1286.jpg: The image contains regions of interest (ROIs).
# Tr-me_1287.jpg: The image contains regions of interest (ROIs).
# Tr-me_1288.jpg: The image contains regions of interest (ROIs).
# Tr-me_1289.jpg: The image contains regions of interest (ROIs).
# Tr-me_1290.jpg: The image contains regions of interest (ROIs).
# Tr-me_1291.jpg: The image contains regions of interest (ROIs).
# Tr-me_1292.jpg: The image contains regions of interest (ROIs).
# Tr-me_1293.jpg: The image contains regions of interest (ROIs).
# Tr-me_1294.jpg: The image contains regions of interest (ROIs).
# Tr-me_1295.jpg: The image contains regions of interest (ROIs).
# Tr-me_1296.jpg: The image contains regions of interest (ROIs).
# Tr-me_1297.jpg: The image contains regions of interest (ROIs).
# Tr-me_1298.jpg: The image contains regions of interest (ROIs).
# Tr-me_1299.jpg: The image contains regions of interest (ROIs).
# Tr-me_1300.jpg: The image contains regions of interest (ROIs).
# Tr-me_1301.jpg: The image contains regions of interest (ROIs).
# Tr-me_1302.jpg: The image contains regions of interest (ROIs).
# Tr-me_1303.jpg: The image contains regions of interest (ROIs).
# Tr-me_1304.jpg: The image contains regions of interest (ROIs).
# Tr-me_1305.jpg: The image contains regions of interest (ROIs).
# Tr-me_1306.jpg: The image contains regions of interest (ROIs).
# Tr-me_1307.jpg: The image contains regions of interest (ROIs).
# Tr-me_1308.jpg: The image contains regions of interest (ROIs).
# Tr-me_1309.jpg: The image contains regions of interest (ROIs).
# Tr-me_1310.jpg: The image contains regions of interest (ROIs).
# Tr-me_1311.jpg: The image contains regions of interest (ROIs).
# Tr-me_1312.jpg: The image contains regions of interest (ROIs).
# Tr-me_1313.jpg: The image contains regions of interest (ROIs).
# Tr-me_1314.jpg: The image contains regions of interest (ROIs).
# Tr-me_1315.jpg: The image contains regions of interest (ROIs).
# Tr-me_1316.jpg: The image contains regions of interest (ROIs).
# Tr-me_1317.jpg: The image contains regions of interest (ROIs).
# Tr-me_1318.jpg: The image contains regions of interest (ROIs).
# Tr-me_1319.jpg: The image contains regions of interest (ROIs).
# Tr-me_1320.jpg: The image contains regions of interest (ROIs).
# Tr-me_1321.jpg: The image contains regions of interest (ROIs).
# Tr-me_1322.jpg: The image contains regions of interest (ROIs).
# Tr-me_1323.jpg: The image contains regions of interest (ROIs).
# Tr-me_1324.jpg: The image contains regions of interest (ROIs).
# Tr-me_1325.jpg: The image contains regions of interest (ROIs).
# Tr-me_1326.jpg: The image contains regions of interest (ROIs).
# Tr-me_1327.jpg: The image contains regions of interest (ROIs).
# Tr-me_1328.jpg: The image contains regions of interest (ROIs).
# Tr-me_1329.jpg: The image contains regions of interest (ROIs).
# Tr-me_1330.jpg: The image contains regions of interest (ROIs).
# Tr-me_1331.jpg: The image contains regions of interest (ROIs).
# Tr-me_1332.jpg: The image contains regions of interest (ROIs).
# Tr-me_1333.jpg: The image contains regions of interest (ROIs).
# Tr-me_1334.jpg: The image contains regions of interest (ROIs).
# Tr-me_1335.jpg: The image contains regions of interest (ROIs).
# Tr-me_1336.jpg: The image contains regions of interest (ROIs).
# Tr-me_1337.jpg: The image contains regions of interest (ROIs).
# Tr-me_1338.jpg: The image contains regions of interest (ROIs).
